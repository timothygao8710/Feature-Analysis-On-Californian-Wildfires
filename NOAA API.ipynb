# %%
#needed to make web requests
import requests

#store the data we get as a dataframe
import pandas as pd

#convert the response as a strcuctured json
import json

#mathematical operations on lists
import numpy as np

#parse the datetimes we get from NOAA
from datetime import datetime

# import matplotlib.pyplot as plt
from meteostat import Point, Daily


from noaa_sdk import NOAA
# https://www1.ncdc.noaa.gov/pub/data/cdo/samples/GHCND_sample_pdf.pdf
#We find the zip code of coordinates, use that as request

#add the access token you got from NOAA
Token = 'iRFNDKRMXHWDkBDwMJRkSHyeHmuwIaPq'
# OpenWeatherKEY = 'dde707fd3b6215808ffdfee52f912d8d'
# weatherapi = 'f7b866d16f5e4b7695931713221703'

# %%
df = pd.read_csv('20kFires.csv')
df['DATE'] = pd.to_datetime(df['DISCOVERY_DATE'] - pd.Timestamp(0).to_julian_date(), unit='D')
print(df.head())
# Out:
#    Unnamed: 0  Unnamed: 0.1  FIRE_YEAR STAT_CAUSE_DESCR   LATITUDE  \
# 0           0             0       2010    Equipment Use  36.766944
# 1           1             1       2010    Miscellaneous  36.776944
# 2           2             2       2010    Miscellaneous  36.856111
# 3           3             3       2010    Miscellaneous  36.818056
# 4           4             4       2010    Miscellaneous  36.883056
#
#     LONGITUDE STATE  DISCOVERY_DATE  FIRE_SIZE       DATE     zipcode  \
# 0 -121.303056    CA       2455335.5       70.0 2010-05-19  95075-9701
# 1 -121.311111    CA       2455355.5        0.5 2010-06-08       95023
# 2 -121.381111    CA       2455359.5        0.1 2010-06-12       95023
# 3 -121.391111    CA       2455361.5        0.1 2010-06-14       95023
# 4 -121.561944    CA       2455388.5        1.0 2010-07-11  95045-9662
#
#                                              address
# 0  Saddle Association Museum, Airline Highway, Tr...
# 1  Pinnacle Hills Golf Club, 7777, Airline Highwa...
# 2  1198, Santa Ana Road, Hollister, San Benito Co...
# 3  186, Hospital Road, Hollister, San Benito Coun...
# 4  Chittenden Road, River Oaks, San Benito County...

# %%
dates_temp = []
dates_prcp = []
temps = []
prcp = []

#for each year from 2015-2019 ...
for year in range(2015, 2020):
    year = str(year)
    print('working on year '+year)
    
    #make the api call
    r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    print('call done')
    #load the api response as a json
    d = json.loads(r.text)
    #get all items in the response which are average temperature readings
    avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']
    #get the date field from all average temperature readings
    dates_temp += [item['date'] for item in avg_temps]
    #get the actual average temperature from all average temperature readings
    temps += [item['value'] for item in avg_temps]
# Out:
# working on year 2015
# call done
# working on year 2016
# call done
# working on year 2017
# call done
# working on year 2018
# call done
# working on year 2019
# call done

# %%
r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate=2005-01-01&enddate=2005-12-31&token=iRFNDKRMXHWDkBDwMJRkSHyeHmuwIaPq')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-17e9335c494a> in <module>
# ----> 1 r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate=2005-01-01&enddate=2005-12-31&token=iRFNDKRMXHWDkBDwMJRkSHyeHmuwIaPq')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:

# %%
r = requests.get('asdf.com')
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-29-4c015db8cc07> in <module>
# ----> 1 r = requests.get('asdf.com')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     526             hooks=hooks,
#     527         )
# --> 528         prep = self.prepare_request(req)
#     529
#     530         proxies = proxies or {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in prepare_request(self, request)
#     454
#     455         p = PreparedRequest()
# --> 456         p.prepare(
#     457             method=request.method.upper(),
#     458             url=request.url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     314
#     315         self.prepare_method(method)
# --> 316         self.prepare_url(url, params)
#     317         self.prepare_headers(headers)
#     318         self.prepare_cookies(cookies)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in prepare_url(self, url, params)
#     388             error = error.format(to_native_string(url, 'utf8'))
#     389
# --> 390             raise MissingSchema(error)
#     391
#     392         if not host:
#
# MissingSchema: Invalid URL 'asdf.com': No schema supplied. Perhaps you meant http://asdf.com?

# %%
# Previous Trials and errors:

# #Long Beach Airport station
# station_id = 'GHCND:USW00023129'

# dates_temp = []
# dates_prcp = []
# temps = []
# prcp = []

# for each year from 2015-2019 ...
for year in range(2015, 2020):
    year = str(year)
    print('working on year '+year)
    
    #make the api call
    r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
    #load the api response as a json
    d = json.loads(r.text)
    print(d)
    #get all items in the response which are average temperature readings
    avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']
    #get the date field from all average temperature readings
    dates_temp += [item['date'] for item in avg_temps]
    #get the actual average temperature from all average temperature readings
    temps += [item['value'] for item in avg_temps]
    
#     #initialize dataframe
# df_temp = pd.DataFrame()

# #populate date and average temperature fields (cast string date to datetime and convert temperature from tenths of Celsius to Fahrenheit)
# df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
# df_temp['avgTemp'] = [float(v)/10.0*1.8 + 32 for v in temps]

#test function inside
# zipcode = '94588'
# dtstr = df['DATE'][0]
# link = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+dtstr+'&enddate='+dtstr
# link = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:' + zipcode + '&startdate=2010-05-01&enddate=2010-05-01'
year = '2011'
r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
# print(link)
    
# r = requests.get(link, headers={'token':Token})
r.raise_for_status()
# print(r)
data = json.loads(r.text)
print(data)
# #REMEMBER THE CAHCE THE RESULTS --> zipcode : date
def getReq(zipcode, datestring):
    link = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&locationid=ZIP:' + zipcode + '&startdate=' + datestring + '&enddate=' + datestring
    r = requests.get(link, headers={'token':Token})
#     r.raise_for_status()
#     print(r)
    #load the api response as a json
    data = json.loads(r.text)
    print(data)

getReq('95075', '2010-02-01')

# https://history.openweathermap.org/data/3.0/history/timemachine?lat={lat}&lon={lon}&dt={dt}&appid={API key}
# link = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+dtstr+'&enddate='+dtstr
# link = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:' + zipcode + '&startdate=2010-05-01&enddate=2010-05-01'
# year = '2011'
lat = '11.51'
lon='-0.13'

link = 'https://power.larc.nasa.gov/api/temporal/daily/point?parameters=T2M,T2MDEW,T2MWET,TS,T2M_RANGE,T2M_MAX,T2M_MIN&community=RE&longitude=' + lon + '&latitude=' + lat + '&start=20100101&end=20100305&format=CSV'
r = requests.get(link)
r.raise_for_status()
# print(r.text)
# data = pd.read_csv(r.text)
# print(data)



# Set time period
start = datetime(2010, 5, 19)
end = datetime(2010, 5, 19)

# Create Point for Vancouver, BC
# vancouver = Point(37.7749, 122.4194, 70)
vancouver = Point(29.3497, -123.1193, 10)

# Get daily data for 2018
data = Daily(vancouver, start, end)
data = data.fetch()
print(data)
# print(data['tavg'][0])
# for i in data:
#     print(i)
# print(type(data))
# Plot line chart including average, minimum and maximum temperature
# data.plot(y=['tavg', 'tmin', 'tmax'])
# plt.show()

bad = 0
for i in range(len(df.index)):
    start = df['DATE'][i]
    end = start
    p = Point(df['LONGITUDE'][i], df['LATITUDE'][i], 70)
#     print(start)
#     print(end)
#     print(df['LONGITUDE'][i])
#     print(df['LATITUDE'][i])
    data = Daily(p, start, end)
    data = data.fetch()
    if len(data.index) == 0:
        bad += 1
        continue
#     print(i)
#     for j in data:
#         df[j][i] = data[j][0]
print(bad)

#https://www.ncdc.noaa.gov/cdo-web/webservices/v2#datasets
#Datasetid=GHCND, the daily summary dataset
#

url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&limit=1000&stationid=GHCND:USW00023129&startdate=2010-01-01&enddate=2010-12-31'
r = requests.get(url)
print(r)
# Out:
# working on year 2015
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-708a00b341cf> in <module>
#      14
#      15     #make the api call
# ---> 16     r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00023129&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
#      17     #load the api response as a json
#      18     d = json.loads(r.text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     351     def connect(self):
#     352         # Add certificate verification
# --> 353         conn = self._new_conn()
#     354         hostname = self.host
#     355         tls_in_tls = False
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     167
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#     171             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84             if source_address:
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#      88
#
# KeyboardInterrupt:
