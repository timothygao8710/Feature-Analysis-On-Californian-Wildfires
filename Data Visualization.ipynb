# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('4Gridded_Small_Fires.csv')
print(df.head())
print(df.columns)
# Out:
#    Unnamed: 0  YEAR  MO  DY  ALLSKY_SFC_LW_DWN  PRECTOT     PS   QV2M  RH2M  \
# 0           0  2020   9  18               5.87     3.13  19.25  10.63  4.32
# 1           1  2020   9  10               1.38     1.81  28.12  11.24  0.98
# 2           2  2020   9   7               3.09     4.40  22.81  17.17  2.47
# 3           3  2020   8  21               3.05     5.91  89.62   4.05  2.06
# 4           4  2020   9  21               3.32     1.95  30.00   7.81  0.95
#
#    SRF_ALB  ...  TROPT  TOA_SW_DNI  TOA_SW_DWN  CLRSKY_SFC_PAR_TOT  EVPTRNS  \
# 0    28.10  ... -68.68       17.52        8.81              116.92      0.0
# 1    18.91  ... -61.99       17.45        8.71               83.10      0.0
# 2    32.38  ... -67.51       17.43        9.15              119.66      0.0
# 3    16.52  ... -70.45       18.62       10.02              129.61      0.0
# 4    15.08  ... -58.15       16.20        8.23              100.30      0.0
#
#    PBLTOP  Longitude  Latitude    Datetime  Fire
# 0   81.98   -116.700    33.862  2020-09-18     1
# 1   86.33   -123.000    39.855  2020-09-10     1
# 2   76.73   -121.473    36.068  2020-09-07     1
# 3   98.29   -121.608    36.151  2020-08-21     1
# 4   74.84   -119.435    37.286  2020-09-21     1
#
# [5 rows x 64 columns]
# Index(['Unnamed: 0', 'YEAR', 'MO', 'DY', 'ALLSKY_SFC_LW_DWN', 'PRECTOT', 'PS',
#        'QV2M', 'RH2M', 'SRF_ALB', 'T10M', 'T10M_MAX', 'T10M_MIN', 'T10M_RANGE',
#        'TQV', 'TS', 'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS2M',
#        'WS2M_MAX', 'WS2M_MIN', 'WS2M_RANGE', 'U10M', 'V10M', 'AIRMASS',
#        'TS_MAX', 'TS_MIN', 'TS_RANGE', 'T2MWET', 'DIRECT_ILLUMINANCE',
#        'DIFFUSE_ILLUMINANCE', 'PW', 'ALLSKY_SFC_UV_INDEX', 'GWETPROF', 'SNODP',
#        'GWETROOT', 'SLP', 'RHOA', 'Z0M', 'GWETTOP', 'TO3', 'T2M', 'T2MDEW',
#        'T2M_RANGE', 'T2M_MAX', 'T2M_MIN', 'DIFF', 'DNR', 'ALLSKY_SFC_UVA',
#        'ALLSKY_SFC_UVB', 'TROPPB', 'TROPQ', 'TROPT', 'TOA_SW_DNI',
#        'TOA_SW_DWN', 'CLRSKY_SFC_PAR_TOT', 'EVPTRNS', 'PBLTOP', 'Longitude',
#        'Latitude', 'Datetime', 'Fire'],
#       dtype='object')

# %%
def bar(feature):
    mp = {}
    for i in df[feature]:
        if(not i in mp) :
            mp[i] = 0
        mp[i] += 1
    fig, ax = plt.subplots(figsize =(20, 14))
    ax.bar(mp.keys(), mp.values())
    plt.title("Bar Graph of " + feature + " Distribution")
    plt.xlabel(feature, fontsize=18)
    plt.ylabel('Frequency', fontsize=16)
    plt.show()

    
def hist(feature):
#     ax.hist(a, bins = [0, 25, 50, 75, 100])
    fig, ax = plt.subplots(figsize =(20, 14))
    ax.hist(df[feature])
    plt.title("Histogram of " + feature + " Distribution")
    plt.xlabel(feature, fontsize=18)
    plt.ylabel('Frequency', fontsize=16)
    plt.show()

    
# bar('MO')
# hist('DIFF')
# bar('T2M')
hist('YEAR')
